# %% [markdown]
# <a href="https://colab.research.google.com/github/xJessicaCamargo/xJessicaCamargo/blob/main/1%C2%BA_dia_Imers%C3%A3o_Alura.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Importei Pandas**

# %%
import pandas as pd
url=("https://gist.githubusercontent.com/tgcsantos/3bdb29eba6ce391e90df2b72205ba891/raw/22fa920e80c9fa209a9fccc8b52d74cc95d1599b/dados_imoveis.csv")
dados= pd.read_csv(url)

# %%
dados.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor
# 0        4          8      6  R$ 7.000.000
# 1        4          4      4  R$ 3.700.000
# 2        4          3      2    R$ 380.000
# 3        3          2      4    R$ 685.000
# 4        3          2      2    R$ 540.000

# %%
dados.sample(10)
# Out:
#                            Rua                             Bairro     Cidade  \
# 4405        Rua Alto do Bonfim  Conjunto Residencial Jardim Canaã  São Paulo
# 8913                       NaN                    Chácara Inglesa  São Paulo
# 7431    Rua Cardoso de Almeida                           Perdizes  São Paulo
# 6805     Rua Irmã Maria Amélia                      Vila Pirituba  São Paulo
# 9512  Rua Bernardino de Campos                         Campo Belo  São Paulo
# 9155                       NaN                Vila Nova Conceição  São Paulo
# 2348     Rua Kalil Filho, 157                        Indianópolis  São Paulo
# 9705              Rua Belgrado                  Vila Moinho Velho  São Paulo
# 3650                       NaN                         Vila Jacuí  São Paulo
# 7251                       NaN                 Paraíso do Morumbi  São Paulo
#
#       Metragem  Quartos  Banheiros  Vagas  \
# 4405       133        3          3      3
# ...

# %% [markdown]
# 1 - Realizar a média da metragem para cara um dos bairros (Paulo)
#
# 2 - 2 formas de selecionar os dados por bairro (consultar os métodos na documentação do pandas) (Thiago)
#
# 3 - Explorar alguns gráficos na documentação e aplicar nas demais colunas do DF, tentar colocar alguma conclusão (Thiago)
#
# 4 - Pegar outros estatísticas dos dados, média, mediana, mim, max (Vivi)
#
# 5 - Descobrir quais são os bairros que não tem nome de Rua. (Vivi)

# %% [markdown]
# # **1 - Realizar Média da metragem para cada um dos bairros**

# %%
dados["Metragem"].mean()
# Out:
# 442.30065947242207

# %%
m_bairro = dados.groupby ("Bairro").Metragem.mean()

# %%
m_bairro
# Out:
# Bairro
# Aclimação            253.056818
# Alto da Boa Vista    418.875000
# Alto da Lapa         294.337209
# Alto da Mooca        270.050000
# Alto de Pinheiros    433.444988
#                         ...
# Vila Água Funda      152.200000
# Água Branca          191.000000
# Água Fria            165.416667
# Água Funda           139.000000
# Água Rasa            340.250000
# Name: Metragem, Length: 701, dtype: float64

# %%
m_bairro.head(5).plot.bar()

# %% [markdown]
# ## **2 - formas de selecionar os dados por bairro (consultar os métodos na documentação do pandas)**

# %%
dados[dados["Bairro"] == "Mooca"]
dados.query('Bairro == "Mooca"')
dados.set_index('Bairro', append=True, drop=False).xs("Mooca", level=1)
# Out:
#                                Rua Bairro     Cidade  Metragem  Quartos  \
# 4         Rua Tobias Barreto, 195   Mooca  São Paulo       100        3
# 109                      Rua Timbó  Mooca  São Paulo       170        3
# 247                            NaN  Mooca  São Paulo        80        2
# 2343             Rua Manuel Galvão  Mooca  São Paulo       106        3
# 2441               Rua Timbó, 130   Mooca  São Paulo       170        3
# 2476             Rua Manuel Galvão  Mooca  São Paulo       111        3
# 2564              Rua dos Pássaros  Mooca  São Paulo       117        3
# 2626              Rua Padre Raposo  Mooca  São Paulo       135        2
# 4326                           NaN  Mooca  São Paulo       101        2
# 4429                           NaN  Mooca  São Paulo       106        2
# 4806                           NaN  Mooca  São Paulo       106        2
# 5866  Rua Conselheiro João Alfredo  Mooca  São Paulo       290        3
# ...

# %% [markdown]
# ## **3 - Explorar alguns gráficos na documentação e aplicar nas demais colunas do DF, tentar colocar alguma conclusão**

# %%
dados["Quartos"].mean()
# Out:
# 3.4831135091926457

# %%
m_quartos = dados.groupby ("Quartos").Metragem.mean()

# %%
m_quartos
# Out:
# Quartos
# 1      196.158879
# 2      155.411715
# 3      274.526703
# 4      473.784527
# 5     1491.523865
# 6      664.695853
# 7      792.553571
# 8      558.950000
# 9      390.083333
# 10     622.750000
# 11     380.000000
# 12     523.500000
# 13     450.000000
# 15     480.000000
# 16     282.500000
# Name: Metragem, dtype: float64

# %%
m_quartos.head(20).plot.bar()
plt.show()

# %% [markdown]
# ## **4 - Pegar outros estatísticas dos dados, média, mediana, mim, max**

# %%
dados.describe()
# Out:
#             Metragem       Quartos     Banheiros         Vagas
# count   10008.000000  10008.000000  10008.000000  10008.000000
# mean      442.300659      3.483114      3.879097      4.097222
# std      7515.379389      1.064200      1.988467      2.824014
# min        10.000000      1.000000      1.000000      1.000000
# 25%       173.000000      3.000000      2.000000      2.000000
# 50%       290.000000      3.000000      4.000000      4.000000
# 75%       460.250000      4.000000      5.000000      5.000000
# max    750000.000000     16.000000     40.000000     50.000000

# %% [markdown]
# # **5 - Descobrir quais são os bairros que não tem nome de Rua**

# %%
dados.isnull().sum().to_frame()
# Out:
#               0
# Rua        3434
# Bairro       12
# Cidade        0
# Metragem      0
# Quartos       0
# Banheiros     0
# Vagas         0
# Valor         0

# %%
dados[dados['Bairro'].isna()]
# Out:
#                                               Rua Bairro     Cidade  Metragem  \
# 7263                 Rua Madalena de Morais, 3773    NaN  São Paulo       742
# 7956                                Rua Vergueiro    NaN  São Paulo       103
# 7996                    Rua Alvorada do Sul, 3773    NaN  São Paulo       678
# 8126         Rua Professor Eduardo Monteiro, 3773    NaN  São Paulo       550
# 8566          Avenida Comendador Adibo Ares, 3773    NaN  São Paulo       694
# 8619                    Rua Alvorada do Sul, 3773    NaN  São Paulo       683
# 8739                    Rua Alvorada do Sul, 3773    NaN  São Paulo       683
# 8868         Rua Professor Eduardo Monteiro, 3773    NaN  São Paulo       555
# 8943                      Rua Santo Eufredo, 3773    NaN  São Paulo       846
# 8992         Rua Professor Eduardo Monteiro, 3773    NaN  São Paulo       555
# 9310  Rua Professor Lúcio Martins Rodrigues, 3773    NaN  São Paulo       358
# ...
